# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
## read the dataset.

df = pd.read_csv('Algerian_forest_fires_dataset.csv', header=0)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 242  26     9  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 243  27     9  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 244  28     9  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 245  29     9  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 246  30     9  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.head()
# Out:
#   day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#      Classes
# 0  not fire
# 1  not fire
# 2  not fire
# 3  not fire
# 4  not fire

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 247 entries, 0 to 246
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.1+ KB

# %%
## Data cleaning.

## check for the missing values.

df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122                            NaN   NaN   NaN         NaN  NaN  NaN   NaN
# 123  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 168                             14     7  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 123   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 168  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
df.head(126)
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 0                                1      6  2012           29   57   18      0
# 1                                2      6  2012           29   61   13    1.3
# 2                                3      6  2012           26   82   22   13.1
# 3                                4      6  2012           25   89   13    2.5
# 4                                5      6  2012           27   77   16      0
# ..                             ...    ...   ...          ...  ...  ...    ...
# 121                             30      9  2012           25   78   14    1.4
# 122                            NaN    NaN   NaN          NaN  NaN  NaN    NaN
# 123  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 124                            day  month  year  Temperature   RH   Ws  Rain
# 125                              1      6  2012           32   71   12    0.7
#
# ...

# %%
## row number 122, 123 and 124 needs to be deleted.

df.drop(index=[122,123,124],inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC   DMC      DC   ISI   BUI  \
# 168  14     7  2012          37  37  18   0.2  88.9  12.9  14.6 9  12.5  10.4
#
#          FWI Classes
# 168  fire          NaN

# %%
## row number 168 needs to be dropped.

df.drop(index=[168],inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature,  RH,  Ws, Rain , FFMC, DMC, DC, ISI, BUI, FWI, Classes  ]
# Index: []

# %%
df.head(125)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 120  29     9  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 125   1     6  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 126   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 127   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
#
#        Classes
# 0    not fire
# ...

# %%
## create a column region to segregate the data set into two region.

df.loc[:121,"Region"]=0
df.loc[125: , "Region"]=1

# %%
df.head(125)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 120  29     9  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 125   1     6  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 126   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 127   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
#
#        Classes    Region
# ...

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head(126)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122   1     6  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 123   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 124   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 125   4     6  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
#
#        Classes    Region
# ...

# %%
## convert the region column into int.

df[['Region']] = df[['Region']].astype(int)

# %%
df.head(126)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0     1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1     2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2     3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3     4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4     5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 121  30     9  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122   1     6  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 123   2     6  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 124   3     6  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 125   4     6  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
#
#        Classes    Region
# ...

# %%
df.iloc[120:125]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 120  29     9  2012          26  80  16   1.8  47.4  2.9  7.7  0.3    3  0.1
# 121  30     9  2012          25  78  14   1.4    45  1.9  7.5  0.2  2.4  0.1
# 122   1     6  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
# 123   2     6  2012          30  73  13     4  55.7  2.7  7.8  0.6  2.9  0.2
# 124   3     6  2012          29  80  14     2  48.7  2.2  7.6  0.3  2.6  0.1
#
#        Classes    Region
# 120  not fire          0
# 121  not fire          0
# 122  not fire          1
# 123  not fire          1
# 124  not fire          1

# %%
## check the columns name. (classes column has more space.)

df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
## fix the space in the columns.

df.columns = df.columns.str.strip()

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
## check the data type of columns.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
df.head(5)
# Out:
#   day month  year Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0   1     6  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1   2     6  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2   3     6  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3   4     6  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4   5     6  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
#
#        Classes  Region
# 0  not fire          0
# 1  not fire          0
# 2  not fire          0
# 3  not fire          0
# 4  not fire          0

# %%
## change the column data type to numerical and categorical.

df[['month','day','year','Temperature','RH','Ws']] = df[['month','day','year','Temperature','RH','Ws']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(7), object(8)
# memory usage: 28.6+ KB

# %%
df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']] = df[['Rain','FFMC','DMC','DC','ISI','BUI','FWI']].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    int64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 28.6+ KB

# %%
df.head(5)
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
## Let's save the clean data set 

df.to_csv('Algerian_forest_fires_dataset_cleaned.csv', index=False)

# %%
## create a copy of cleaned data frame.

df_copy = df.copy()

## df_copy = df - this would not work because any changes in df would be reflected in df_copy as both data frames refer same memory.

# %%
## df = df_copy.copy()

# %% [markdown]
# ## EDA and Feature engineering starting...

# %%
df
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# ...

# %%
## for instance, FWI is considered as output column for regression problem.

## for instance, classes is considered as output column for classification problem.

## Day, Month and Year column don't seem to add any information for the output column as they are interval.

df1 = df.drop(columns=['day','month','year'])

# %%
df1
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 0     not fire          0
# 1     not fire          0
# 2     not fire          0
# 3     not fire          0
# 4     not fire          0
# ...

# %%
## for regression problem, encoding the classes column.

## check the distinct values of the column.

df1['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
## trimmming the values and then checking the count.

df1['Classes'].str.contains('not fire').value_counts()
# Out:
# Classes
# False    137
# True     106
# Name: count, dtype: int64

# %%
df1['Classes'] = np.where(df1['Classes'].str.contains('not fire'),0,1)

# %%
df1
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..  ..   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# 3         0
# ...

# %%
df1['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %% [markdown]
# ## Visualization starting now...

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
## plot the density plot for all features.

plt.style.use('seaborn-v0_8')

df1.hist(bins=50, figsize=(20,15))
plt.show()

# %%
## Percentage for pie chart.

df1['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
df1['Classes'].value_counts(normalize=True)
# Out:
# Classes
# 1    0.563786
# 0    0.436214
# Name: proportion, dtype: float64

# %%
df1['Classes'].value_counts(normalize=True)*100
# Out:
# Classes
# 1    56.378601
# 0    43.621399
# Name: proportion, dtype: float64

# %%
## plotting pie chart.

classlables = ["Fire", "Not Fire"]
plt.figure(figsize=(3,3))
plt.pie(df1['Classes'].value_counts(normalize=True)*100, labels=classlables, autopct='%1.1f%%')
plt.show()

# %%
## Correlation 

df1.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
## graphical way to show the correlation.

sns.heatmap(df1.corr())
# Out:
# <Axes: >

# %%
## since, FWI is the output variable, lets us see the box plot of FWI.

sns.boxplot(df1['FWI'], color='b')
# Out:
# <Axes: ylabel='FWI'>

# %%
## Lets see in which month the fire is there.

df_copy
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 0      1      6  2012           29  57  18   0.0  65.7   3.4   7.6  1.3   3.4
# 1      2      6  2012           29  61  13   1.3  64.4   4.1   7.6  1.0   3.9
# 2      3      6  2012           26  82  22  13.1  47.1   2.5   7.1  0.3   2.7
# 3      4      6  2012           25  89  13   2.5  28.6   1.3   6.9  0.0   1.7
# 4      5      6  2012           27  77  16   0.0  64.8   3.0  14.2  1.2   3.9
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...  ...   ...
# 238   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 239   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 240   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 241   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 242   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI       Classes  Region
# ...

# %%
plt.subplots(figsize=(15,5))
sns.countplot(x='month', hue='Classes',data=df_copy)
plt.title("Monthly fire analysis")

plt.show()

# %%
## arrange the values of classes column.
df_copy['Classes'] = np.where(df['Classes'].str.contains('not fire'),'Not_Fire','Fire')

plt.subplots(figsize=(15,5))
sns.countplot(x='month', hue='Classes',data=df_copy)
plt.title("Monthly fire analysis")
plt.xlabel("Month Number Of The Year", weight='bold')
plt.ylabel("Count Of Instance of Fire", weight='bold')
plt.show()

# %%
plt.subplots(figsize=(15,5))
ax = sns.countplot(x='month', hue='Classes', data=df_copy[df_copy['Region']==1])
plt.title("Sidi-Bel Region Fire Analysis")
plt.xlabel("Month Number Of The Year", weight='bold')
plt.ylabel("Count Of Instance of Fire", weight='bold')

# Iterate through the patches (bars) and add the annotations
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')

plt.show()

# %%
plt.subplots(figsize=(15,5))
ax = sns.countplot(x='month', hue='Classes', data=df_copy[df_copy['Region']==0])
plt.title("Bejaia Region Fire Analysis")
plt.xlabel("Month Number Of The Year", weight='bold')
plt.ylabel("Count Of Instance of Fire", weight='bold')

# Iterate through the patches (bars) and add the annotations
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2., height),
                ha='center', va='center', xytext=(0, 5), textcoords='offset points')
    
plt.show()
