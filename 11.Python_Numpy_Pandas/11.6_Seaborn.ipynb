# %%
import seaborn as sns

# %%
## Basic plotting with seaborn.

tips_data=sns.load_dataset('tips')

tips_data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
## Scatter plot.
import matplotlib.pyplot as plt

sns.scatterplot(x='total_bill',y='tip',data=tips_data)
plt.title('Scatter plot for total bills vs tips')
plt.show()

# %%
## line plot.

sns.lineplot(x='size',y='total_bill',data=tips_data)
plt.title('Line plot for total bills vs size')
plt.show()

# %%
## Categorical variable Plot.

sns.barplot(x='day',y='total_bill',data=tips_data)
plt.title('Bar plot for total bills vs days')
plt.show()

# %%
## Box plot.

sns.boxplot(x='day',y='total_bill', data=tips_data)
plt.title('box plot for total bills vs size')
plt.show()

# %%
## Violine plot.

sns.violinplot(x='day',y='total_bill',data=tips_data)
plt.title('Violin plot for total bills vs day')
plt.show()

# %%
plt.figure(figsize=(15,5))

plt.subplot(1,2,1)
sns.boxplot(x='day',y='total_bill', data=tips_data)
plt.title('box plot for total bills vs size')

plt.subplot(1,2,2)
sns.violinplot(x='day',y='total_bill',data=tips_data)
plt.title('Violin plot for total bills vs size')
plt.show()

# %%
## Histogram plot.
sns.histplot(tips_data['total_bill'],bins=10, kde=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
## KDE - Kernel Density Plot.

sns.kdeplot(tips_data['total_bill'],fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
## Pair plot.

sns.pairplot(tips_data)

# %%
## Correlation.

## Heatmap

my_corr = tips_data[['total_bill','tip','size']].corr()
my_corr
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(my_corr,annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
## Customization of plot.

import pandas as pd
import numpy as np

# %%
sale_df=pd.read_csv('sales_data.csv')

sale_df.head(5)
# Out:
#    Transaction ID        Date Product Category             Product Name  \
# 0           10001  2024-01-01      Electronics            iPhone 14 Pro
# 1           10002  2024-01-02  Home Appliances         Dyson V11 Vacuum
# 2           10003  2024-01-03         Clothing         Levi's 501 Jeans
# 3           10004  2024-01-04            Books        The Da Vinci Code
# 4           10005  2024-01-05  Beauty Products  Neutrogena Skincare Set
#
#    Units Sold  Unit Price  Total Revenue         Region Payment Method
# 0           2      999.99        1999.98  North America    Credit Card
# 1           1      499.99         499.99         Europe         PayPal
# 2           3       69.99         209.97           Asia     Debit Card
# 3           4       15.99          63.96  North America    Credit Card
# 4           1       89.99          89.99         Europe         PayPal

# %%
## plot total sales by product.

plt.figure(figsize=(10,5))
sns.barplot(x='Product Category',y='Total Revenue', data=sale_df, estimator=sum)
plt.title('Total sales by product')
plt.xlabel('Product_Category')
plt.ylabel('Total_Revenue')
plt.show()

# %%
sale_df
# Out:
#      Transaction ID        Date Product Category  \
# 0             10001  2024-01-01      Electronics
# 1             10002  2024-01-02  Home Appliances
# 2             10003  2024-01-03         Clothing
# 3             10004  2024-01-04            Books
# 4             10005  2024-01-05  Beauty Products
# ..              ...         ...              ...
# 235           10236  2024-08-23  Home Appliances
# 236           10237  2024-08-24         Clothing
# 237           10238  2024-08-25            Books
# 238           10239  2024-08-26  Beauty Products
# 239           10240  2024-08-27           Sports
#
#                                         Product Name  Units Sold  Unit Price  \
# 0                                      iPhone 14 Pro           2      999.99
# 1                                   Dyson V11 Vacuum           1      499.99
# 2                                   Levi's 501 Jeans           3       69.99
# ...

# %%
sale_df_sorted = sale_df.groupby('Product Category')['Total Revenue'].sum().reset_index()

sale_df_sorted
# Out:
#   Product Category  Total Revenue
# 0  Beauty Products        2621.90
# 1            Books        1861.93
# 2         Clothing        8128.93
# 3      Electronics       34982.41
# 4  Home Appliances       18646.16
# 5           Sports       14326.52

# %%
sale_df_sorted_tr = sale_df_sorted.sort_values(by='Total Revenue')

sale_df_sorted_tr
# Out:
#   Product Category  Total Revenue
# 1            Books        1861.93
# 0  Beauty Products        2621.90
# 2         Clothing        8128.93
# 5           Sports       14326.52
# 4  Home Appliances       18646.16
# 3      Electronics       34982.41

# %%
# Plot of Product Category vs total revenue.

plt.figure(figsize=(10,5))
sns.barplot(x='Product Category',y='Total Revenue', data=sale_df_sorted_tr, estimator=sum)
plt.title('Total sales by product')
plt.xlabel('Product_Category')
plt.ylabel('Total_Revenue')
plt.show()

# %%
# Plot of Product Category vs total revenue.

sale_df_sorted_pc = sale_df_sorted.sort_values(by='Product Category')

plt.figure(figsize=(10,5))
sns.barplot(x='Product Category',y='Total Revenue', data=sale_df_sorted_pc, estimator=sum, hue='Product Category')
plt.title('Total sales by product')
plt.xlabel('Product_Category')
plt.ylabel('Total_Revenue')

plt.savefig('pc_revenue.png', dpi=30, transparent=True, bbox_inches='tight')

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Example data
tips = sns.load_dataset('tips')

plt.figure(figsize=(15,18))

plt.subplot(2,2,1)
# KDE plot using Seaborn
sns.kdeplot(data=tips['total_bill'], fill=True)
plt.title('Kernel Density Estimation of Total Bill')
plt.xlabel('Total Bill ($)')
plt.ylabel('Density')

plt.subplot(2,2,2)
sns.histplot(data=tips['total_bill'], kde=True)
plt.title('Kernel Density Estimation of Total Bill')
plt.xlabel('Total Bill ($)')
plt.ylabel('Density')

plt.subplot(2,2,3)
# KDE plot using Seaborn
sns.boxplot(data=tips['total_bill'], fill=True)
plt.title('Kernel Density Estimation of Total Bill')
plt.xlabel('Total Bill ($)')
plt.ylabel('Density')

plt.subplot(2,2,4)
sns.violinplot(data=tips['total_bill'],)
plt.title('Kernel Density Estimation of Total Bill')
plt.xlabel('Total Bill ($)')
plt.ylabel('Density')


plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Load example dataset from Seaborn
iris = sns.load_dataset('iris')

iris

# Create a pair plot for numerical variables
sns.pairplot(iris)
plt.show()

# %%
# Load example dataset
tips = sns.load_dataset('tips')
tips
correlation_matrix = tips[['total_bill','tip','size']].corr()
correlation_matrix
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
# Create heatmap of the correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips_gt_5 = tips[tips['tip']>5]

tips_le_5 = tips[tips['tip']<=5]

tips_le_5
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [226 rows x 7 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Create a sample DataFrame with NaN values
data = {'A': [1, 2, 3, None, 5], 'B': [5, None, 7, 8, 9]}
df = pd.DataFrame(data)

df
# Out:
#      A    B
# 0  1.0  5.0
# 1  2.0  NaN
# 2  3.0  7.0
# 3  NaN  8.0
# 4  5.0  9.0

# %%
# Scatter plot ignoring NaN values
sns.scatterplot(x='A', y='B', data=df)
plt.title('Scatter Plot with Missing Data')
plt.show()

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(tips,x='total_bill',y='tip')
plt.show()

# %%
g = sns.FacetGrid(tips, col='sex')
g.map(sns.scatterplot, 'total_bill', 'tip')
plt.show()
, row='time'

# %%
g = sns.FacetGrid(tips, col='time')
g.map(sns.scatterplot, 'total_bill', 'tip')
plt.show()

# %%
g = sns.FacetGrid(tips, col='sex', row='time')
g.map(sns.scatterplot, 'total_bill', 'tip')
plt.show()

# %%
g = sns.PairGrid(tips, hue='sex')
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.histplot)
g.add_legend()
plt.show()

# %%
sns.catplot(x='day', y='total_bill', hue='sex', kind='box', data=tips)
plt.title('Box Plot of Total Bill by Day')
plt.show()

# %%
# Example of a violin plot
sns.catplot(x='day', y='total_bill', hue='sex', kind='violin', data=tips, split=True)
plt.title('Violin Plot of Total Bill by Day')
plt.show()

# %%
# Out:
# pyth
